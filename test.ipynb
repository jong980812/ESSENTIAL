# %%
import pickle
with open('/data/gyeongho/framework/videoCIL/data/activitynet/ActivityNet_data_10tasks.pkl', 'rb') as file:
    data = pickle.load(file)

# %%
data_list = data['train']

# %%
total_length = sum(len(values) for directory in data_list for values in directory.values())

print(total_length)  # 출력: 9
# Out:
# 15410

# %%
7654
15410

# %%
train tar files count:
4820
val tar files count:
2384
train_val tar files count:
7749

# %%
2384 + 7749 +4820
# Out:
# 14953

# %%
mkdir videos
mv v1-2/train/* videos/
mv v1-2/val/* videos/
mv v1-3/train_val/* videos/
# Out:
#   Cell In[4], line 1
#     mv v1-2/train/* videos/
#        ^
# SyntaxError: invalid syntax
