# %%
import pickle
with open('/data/gyeongho/framework/videoCIL/data/activitynet/ActivityNet_data_10tasks.pkl', 'rb') as file:
    data = pickle.load(file)

# %%
data_list = data['train'][0]
data_list_val = data['val'][0]
print(data_list.keys())
print(data_list_val.keys())
# Out:
# dict_keys(['Making a lemonade', 'Hula hoop', 'Disc dog', 'Playing ten pins', 'Plastering', 'Laying tile', 'Playing squash', 'Using the rowing machine', 'Discus throw', 'Grooming dog', 'Shot put', 'Walking the dog', 'Preparing pasta', 'Doing kickboxing', 'Playing kickball', 'Making a sandwich', 'Hurling', 'BMX', 'Making a cake', 'Playing rubik cube'])
# dict_keys(['Making a lemonade', 'Hula hoop', 'Disc dog', 'Playing ten pins', 'Plastering', 'Laying tile', 'Playing squash', 'Using the rowing machine', 'Discus throw', 'Grooming dog', 'Shot put', 'Walking the dog', 'Preparing pasta', 'Doing kickboxing', 'Playing kickball', 'Making a sandwich', 'Hurling', 'BMX', 'Making a cake', 'Playing rubik cube'])

# %%
for label_num, (label_name, videos) in enumerate(data_list.items()):
    for video_info in videos:
        print(label_num,label_name)
# Out:
# 0 Making a lemonade
# 0 Making a lemonade
# 0 Making a lemonade
# 0 Making a lemonade
# 0 Making a lemonade
# 0 Making a lemonade
# 0 Making a lemonade
# 0 Making a lemonade
# 0 Making a lemonade
# 0 Making a lemonade
# 0 Making a lemonade
# 0 Making a lemonade
# 0 Making a lemonade
# 0 Making a lemonade
# 0 Making a lemonade
# 0 Making a lemonade
# 0 Making a lemonade
# 0 Making a lemonade
# 0 Making a lemonade
# 0 Making a lemonade
# 0 Making a lemonade
# 0 Making a lemonade
# 0 Making a lemonade
# 0 Making a lemonade
# 0 Making a lemonade
# 0 Making a lemonade
# 0 Making a lemonade
# 0 Making a lemonade
# 0 Making a lemonade
# 0 Making a lemonade
# 0 Making a lemonade
# 0 Making a lemonade
# 0 Making a lemonade
# 0 Making a lemonade
# 0 Making a lemonade
# 0 Making a lemonade
# 0 Making a lemonade
# 0 Making a lemonade
# 0 Making a lemonade
# 0 Making a lemonade
# 0 Making a lemonade
# 0 Making a lemonade
# 0 Making a lemonade
# 0 Making a lemonade
# 0 Making a lemonade
# ...

# %%
total_length = sum(len(values) for directory in data_list for values in directory.values())

print(total_length)  # 출력: 9
# Out:
# 15410

# %%
7654
15410

# %%
train tar files count:
4820
val tar files count:
2384
train_val tar files count:
7749

# %%
for k,v in data_list.items():
    for video_info in v:
        # start_ratio= round(float(video_info['t_start']) / float(video_info['video_duration']),3)
        # end_ratio= round(float(video_info['t_end']) / float(video_info['video_duration']),3)
        start_ratio= float(video_info['t_start']) / float(video_info['video_duration'])
        end_ratio= float(video_info['t_end']) / float(video_info['video_duration'])
        if (end_ratio-start_ratio) < 0.01:
            print(end_ratio-start_ratio)
            print((end_ratio-start_ratio)*float(video_info['video_frames']))
            # print(video_info['filename'])
# Out:
# 0.004682346719752151
# 20.405667004679874
# 0.0078025607679908515
# 28.20625717628693
# 0.00780156531433418
# 30.58993759750432
# 0.00936373367405624
# 52.50245471043334
# 0.006241161546253093
# 26.905647425897087
# 0.007802933176033311
# 39.45943307120045
# 0.007802025686109576
# 29.47605304212198
# 0.00037460157457458454
# 0.24161801560060703
# 0.009365187921815066
# 26.016492046802252
# 0.007801838960350874
# 33.07979719188771
# 0.009370674059451578
# 33.61260785125281
# 0.00018518518518518518
# 0.3
# 0.007803380903526391
# 38.291190093604
# 0.004681299016666585
# 12.414804992199782
# 0.007802165027777641
# 20.691341653666303
